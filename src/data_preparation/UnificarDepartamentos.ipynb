# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn

from pathlib import Path
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
# Configuraciones
data_path = '../../data/'
file_preffix = 'EXA_2022-1_'

# %%
# Cargamos todas las bases por departamento
states = ['AMAZONAS', 'GUAINIA', 'GUAVIARE', 'VAUPES', 'VICHADA']

bases = {}

for state in states:
    file_path = f'{data_path}raw/{file_preffix}{state}.csv'
    bases[state.lower()] = pd.read_csv(file_path, sep='|')

base_amazonas = bases['amazonas']
base_guainia = bases['guainia']
base_guaviare = bases['guaviare']
base_vaupes = bases['vaupes']
base_vichada = bases['vichada']

# %%
# Unificamos las bases en un solo dataframe
base = pd.concat([base_amazonas, base_guainia, base_guaviare, base_vaupes, base_vichada], ignore_index=True)
base
# Out:
#         ESTU_CONSECUTIVO ESTU_FECHAPRESENTACION  ESTU_GRADO ESTU_GENERO  \
# 0               22886860             30/05/2022           6           F
# 1               22884841             23/05/2022           6           M
# 2               22888380             11/06/2022           5           M
# 3               22972309             09/06/2022           8           M
# 4               23572970             24/05/2022           3           M
# ...                  ...                    ...         ...         ...
# 372557          22000211             27/05/2022          11           F
# 372558          21999980             04/05/2022           7           M
# 372559           1330356             30/04/2022          10           F
# 372560           1326811             23/05/2022           9           F
# 372561           1330362             30/04/2022           9           F
#
#         COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 0                        191001000012        191001000012
# 1                        191001000012        191001000012
# 2                        191001000012        191001000047
# 3                        191540000051        191540000051
# 4                        191001000489        191001000489
# ...                               ...                 ...
# 372557                   499001001919        499001001919
# 372558                   299496000132        299496000132
# 372559                   299496000132        299496000132
# 372560                   299001001626        299001001626
# 372561                   299496000132        299496000132
#
#                                  COLE_NOM_ESTABLECIMIENTO  \
# 0       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# 1       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# 2       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# 3              I.E. INTERNADO SAN FRANCISCO DE LORETOYACO
# 4          INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS
# ...                                                   ...
# 372557          I.E. INTERNADO SANTA TERESITA DEL TUPARRO
# 372558                       I.E. INTERNADO CAMILO TORRES
# 372559                       I.E. INTERNADO CAMILO TORRES
# 372560                       I.E. INTERNADO SAN BARTOLOME
# 372561                       I.E. INTERNADO CAMILO TORRES
#
#                                             COLE_NOM_SEDE  COLE_COD_ICFES  \
# 0       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           19505
# 1       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           19505
# 2                                    SEDE VICENTE DE PAUL           19507
# 3       I.E. INTERNADO SAN FRANCISCO DE LORETOYACO - S...           13116
# 4          I.E. SAGRADO CORAZON DE JESUS - SEDE PRINCIPAL           13110
# ...                                                   ...             ...
# 372557  I.E. INTERNADO SANTA TERESITA DEL TUPARRO - SE...           51930
# 372558      I.E. INTERNADO CAMILO TORRES - SEDE PRINCIPAL           13044
# 372559      I.E. INTERNADO CAMILO TORRES - SEDE PRINCIPAL           13044
# 372560      I.E. INTERNADO SAN BARTOLOME - SEDE PRINCIPAL           38674
# 372561      I.E. INTERNADO CAMILO TORRES - SEDE PRINCIPAL           13044
#
#        COLE_NATURALEZA  ...                                 EXA_INSTRUMENTO  \
# 0                    O  ...  Competencias Ciudadanas: Pensamiento Ciudadano
# 1                    O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 2                    O  ...        Ciencias Naturales y Educación Ambiental
# 3                    O  ...                                     Matemáticas
# 4                    O  ...                                     Matemáticas
# ...                ...  ...                                             ...
# 372557               O  ...                                          Inglés
# 372558               O  ...                                     Matemáticas
# 372559               O  ...                                          Inglés
# 372560               O  ...                                          Inglés
# 372561               O  ...                                          Inglés
#
#               EXA_COMPONENTE                        EXA_COMPETENCIA  \
# 0       No aplica componente  Argumentación en contextos ciudadanos
# 1       No aplica componente                    Comprensión lectora
# 2               Entorno vivo                             Indagación
# 3                  Aleatorio                Resolución de problemas
# 4       Numérico Variacional                           Comunicación
# ...                      ...                                    ...
# 372557               Parte 5                               Nivel A2
# 372558             Aleatorio                           Comunicación
# 372559               Parte 1                               Nivel A1
# 372560               Parte 4                               Nivel A1
# 372561               Parte 3                               Nivel A1
#
#        EXA_N_PREGUNTAS  EXA_N_PREGUNTAS_OM EXA_PRC_PREGUNTAS_OM  \
# 0                    4                 0.0                  0.0
# 1                   20                 0.0                  0.0
# 2                    2                 0.0                  0.0
# 3                    3                 0.0                  0.0
# 4                    2                 0.0                  0.0
# ...                ...                 ...                  ...
# 372557               2                 2.0                100.0
# 372558               2                 0.0                  0.0
# 372559               1                 0.0                  0.0
# 372560               1                 0.0                  0.0
# 372561               1                 0.0                  0.0
#
#         EXA_N_RTAS_CORR EXA_N_RTAS_NOCORR EXA_PRC_RTAS_CORR  \
# 0                   0.0               4.0              0.00
# 1                  17.0               3.0             85.00
# 2                   2.0               0.0            100.00
# 3                   2.0               1.0             66.67
# 4                   0.0               2.0              0.00
# ...                 ...               ...               ...
# 372557              0.0               0.0              0.00
# 372558              0.0               2.0              0.00
# 372559              1.0               0.0            100.00
# 372560              1.0               0.0            100.00
# 372561              1.0               0.0            100.00
#
#        EXA_PRC_RTAS_NOCORR
# 0                   100.00
# 1                    15.00
# 2                     0.00
# 3                    33.33
# 4                   100.00
# ...                    ...
# 372557                0.00
# 372558              100.00
# 372559                0.00
# 372560                0.00
# 372561                0.00
#
# [372562 rows x 28 columns]

# %%
# Obtener solo los registros del instrumento comprensión lectora
base_lec = base[base['EXA_COMPETENCIA']=='Comprensión lectora']

# Se eliminan los registros duplicados
base_lec_unique = base_lec.drop_duplicates(['ESTU_CONSECUTIVO'], keep='first')
base_lec_unique
# Out:
#         ESTU_CONSECUTIVO ESTU_FECHAPRESENTACION  ESTU_GRADO ESTU_GENERO  \
# 1               22884841             23/05/2022           6           M
# 9               22888972             27/05/2022           9           F
# 13              22861481             22/05/2022          10           F
# 14              22970239             15/06/2022           5           F
# 83              22891079             22/05/2022          10           F
# ...                  ...                    ...         ...         ...
# 372443          21990399             25/05/2022           5           F
# 372444           1293291             11/05/2022           6           F
# 372454          21994388             01/06/2022           4           F
# 372456          21990395             27/05/2022           7           M
# 372482          21989595             07/06/2022           5           F
#
#         COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 1                        191001000012        191001000012
# 9                        191001000012        191001000012
# 13                       191001000012        191001000012
# 14                       191540000051        191540000051
# 83                       191001000012        191001000012
# ...                               ...                 ...
# 372443                   299524000194        299524000194
# 372444                   199001001974        199001001974
# 372454                   299572000082        299001002126
# 372456                   299524000194        299524000194
# 372482                   299572000244        299572000244
#
#                                  COLE_NOM_ESTABLECIMIENTO  \
# 1       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# 9       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# 13      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# 14             I.E. INTERNADO SAN FRANCISCO DE LORETOYACO
# 83      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...
# ...                                                   ...
# 372443                                  C.E. EL TROMPILLO
# 372444                              I.E. SOLMERIDA BUILES
# 372454                           I.E. INTERNADO CADANAPAY
# 372456                                  C.E. EL TROMPILLO
# 372482                      I.E. SAGRADO CORAZON DE JESUS
#
#                                             COLE_NOM_SEDE  COLE_COD_ICFES  \
# 1       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           19505
# 9       I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           19502
# 13      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           19502
# 14      I.E. INTERNADO SAN FRANCISCO DE LORETOYACO - S...           13116
# 83      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           19502
# ...                                                   ...             ...
# 372443                  C.E. EL TROMPILLO - SEDE PRINCPAL            6640
# 372444             I.E. SOLMERIDA BUILES - SEDE PRINCIPAL           13029
# 372454                                           TARRAPAY           13069
# 372456                  C.E. EL TROMPILLO - SEDE PRINCPAL            6640
# 372482      I.E SAGRADO CORAZÓN DE JESUS - SEDE PRINCIPAL           45269
#
#        COLE_NATURALEZA  ...                                 EXA_INSTRUMENTO  \
# 1                    O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 9                    O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 13                   O  ...                                 Lectura Crítica
# 14                   O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 83                   O  ...                                 Lectura Crítica
# ...                ...  ...                                             ...
# 372443               O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 372444               O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 372454               O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 372456               O  ...  Competencias Comunicativas en Lenguaje:Lectura
# 372482               O  ...  Competencias Comunicativas en Lenguaje:Lectura
#
#               EXA_COMPONENTE      EXA_COMPETENCIA EXA_N_PREGUNTAS  \
# 1       No aplica componente  Comprensión lectora              20
# 9       No aplica componente  Comprensión lectora              20
# 13      No aplica componente  Comprensión lectora              20
# 14      No aplica componente  Comprensión lectora              20
# 83      No aplica componente  Comprensión lectora              20
# ...                      ...                  ...             ...
# 372443  No aplica componente  Comprensión lectora              20
# 372444  No aplica componente  Comprensión lectora              20
# 372454  No aplica componente  Comprensión lectora              20
# 372456  No aplica componente  Comprensión lectora              20
# 372482  No aplica componente  Comprensión lectora              20
#
#         EXA_N_PREGUNTAS_OM EXA_PRC_PREGUNTAS_OM  EXA_N_RTAS_CORR  \
# 1                      0.0                  0.0             17.0
# 9                      0.0                  0.0              8.0
# 13                     0.0                  0.0             10.0
# 14                     0.0                  0.0             10.0
# 83                     0.0                  0.0              8.0
# ...                    ...                  ...              ...
# 372443                 0.0                  0.0              6.0
# 372444                 0.0                  0.0             16.0
# 372454                 0.0                  0.0              7.0
# 372456                 0.0                  0.0             18.0
# 372482                 3.0                 15.0              5.0
#
#        EXA_N_RTAS_NOCORR EXA_PRC_RTAS_CORR EXA_PRC_RTAS_NOCORR
# 1                    3.0              85.0                15.0
# 9                   12.0              40.0                60.0
# 13                  10.0              50.0                50.0
# 14                  10.0              50.0                50.0
# 83                  12.0              40.0                60.0
# ...                  ...               ...                 ...
# 372443              14.0              30.0                70.0
# 372444               4.0              80.0                20.0
# 372454              13.0              35.0                65.0
# 372456               2.0              90.0                10.0
# 372482              12.0              25.0                60.0
#
# [17885 rows x 28 columns]

# %%
# Se verifica que no exista más de 1 registro por estudiante
base_lec_unique.groupby(['ESTU_CONSECUTIVO'])['ESTU_CONSECUTIVO'].filter(lambda x: len(x) > 1)
# Out:
# Series([], Name: ESTU_CONSECUTIVO, dtype: int64)

# %%
# Sumar numero de respuestas por instrumento y fecha
base_grouped = base.groupby(['ESTU_CONSECUTIVO', 'ESTU_FECHAPRESENTACION', 'EXA_INSTRUMENTO'])['EXA_N_RTAS_CORR'].sum()
base_grouped = pd.DataFrame(base_grouped).reset_index().sort_values(by=['ESTU_CONSECUTIVO', 'ESTU_FECHAPRESENTACION', 'EXA_INSTRUMENTO'])
base_grouped
# Out:
#        ESTU_CONSECUTIVO ESTU_FECHAPRESENTACION  \
# 0                 25622             27/05/2022
# 1                 25622             27/05/2022
# 2                118033             18/05/2022
# 3                118033             25/05/2022
# 4                118033             25/05/2022
# ...                 ...                    ...
# 66644          23931572             19/06/2022
# 66645          23932246             08/05/2022
# 66646          23932246             09/05/2022
# 66647          23932418             04/05/2022
# 66648          23932418             09/05/2022
#
#                                       EXA_INSTRUMENTO  EXA_N_RTAS_CORR
# 0            Ciencias Naturales y Educación Ambiental              8.0
# 1      Competencias Comunicativas en Lenguaje:Lectura             16.0
# 2                                         Matemáticas             14.0
# 3                                  Ciencias Naturales             12.0
# 4                                     Lectura Crítica              6.0
# ...                                               ...              ...
# 66644                                     Matemáticas              7.0
# 66645  Competencias Comunicativas en Lenguaje:Lectura              4.0
# 66646                                     Matemáticas              6.0
# 66647  Competencias Comunicativas en Lenguaje:Lectura             28.0
# 66648                                     Matemáticas             15.0
#
# [66649 rows x 4 columns]

# %%
# Sumar la cantidad de respuestas correctas por instrumento por estudiante
base_columns = ['ESTU_CONSECUTIVO', 'ESTU_FECHAPRESENTACION']

base_pivot = pd.pivot_table(base_grouped,
                             index=['ESTU_CONSECUTIVO'],
                             columns=["EXA_INSTRUMENTO"],
                             values=["EXA_N_RTAS_CORR"],
                             aggfunc="sum",
                             fill_value=0)

base_pivot.columns = base_pivot.columns.droplevel()
pivoted = base_pivot.groupby(['ESTU_CONSECUTIVO']).max().sort_values(by=['ESTU_CONSECUTIVO']).reset_index()
pivoted
# Out:
# EXA_INSTRUMENTO  ESTU_CONSECUTIVO  Ciencias Naturales  \
# 0                           25622                 0.0
# 1                          118033                12.0
# 2                          196762                 0.0
# 3                          196957                 0.0
# 4                          396680                15.0
# ...                           ...                 ...
# 19648                    23930490                 0.0
# 19649                    23931074                 0.0
# 19650                    23931572                 0.0
# 19651                    23932246                 0.0
# 19652                    23932418                 0.0
#
# EXA_INSTRUMENTO  Ciencias Naturales y Educación Ambiental  \
# 0                                                     8.0
# 1                                                     0.0
# 2                                                     2.0
# 3                                                     6.0
# 4                                                     0.0
# ...                                                   ...
# 19648                                                 0.0
# 19649                                                 0.0
# 19650                                                 0.0
# 19651                                                 0.0
# 19652                                                 0.0
#
# EXA_INSTRUMENTO  Competencias Ciudadanas: Pensamiento Ciudadano  \
# 0                                                           0.0
# 1                                                           0.0
# 2                                                           2.0
# 3                                                          12.0
# 4                                                           0.0
# ...                                                         ...
# 19648                                                       0.0
# 19649                                                       0.0
# 19650                                                       0.0
# 19651                                                       0.0
# 19652                                                       0.0
#
# EXA_INSTRUMENTO  Competencias Comunicativas en Lenguaje:Lectura  Inglés  \
# 0                                                          16.0     0.0
# 1                                                           0.0    12.0
# 2                                                           3.0     0.0
# 3                                                          17.0     0.0
# 4                                                           0.0    15.0
# ...                                                         ...     ...
# 19648                                                       9.0     0.0
# 19649                                                      12.0     0.0
# 19650                                                      11.0     0.0
# 19651                                                       4.0     0.0
# 19652                                                      28.0     0.0
#
# EXA_INSTRUMENTO  Lectura Crítica  Matemáticas  Sociales y Ciudadanas
# 0                            0.0          0.0                    0.0
# 1                            6.0         14.0                    8.0
# 2                            0.0          3.0                    0.0
# 3                            0.0         12.0                    0.0
# 4                            9.0          7.0                   12.0
# ...                          ...          ...                    ...
# 19648                        0.0          5.0                    0.0
# 19649                        0.0          8.0                    0.0
# 19650                        0.0          7.0                    0.0
# 19651                        0.0          6.0                    0.0
# 19652                        0.0         15.0                    0.0
#
# [19653 rows x 9 columns]

# %%
# Hacemos merge de la base inicial de instrumento de lectura por estudiante con la sumatoria de respuestas correctas por otro instrumentos.
summarized = pd.merge(base_lec_unique, pivoted, on='ESTU_CONSECUTIVO', how='left')
summarized = summarized.sort_values(by=['COLE_NOM_DPTO', 'COLE_COD_ICFES', 'ESTU_CONSECUTIVO', 'ESTU_FECHAPRESENTACION', 'EXA_INSTRUMENTO'])
summarized.to_csv(f'{data_path}processed/{file_preffix}Todos.csv')
summarized
# Out:
#        ESTU_CONSECUTIVO ESTU_FECHAPRESENTACION  ESTU_GRADO ESTU_GENERO  \
# 332            22857330             26/05/2022           3           M
# 1758           22857841             24/05/2022           3           F
# 526            22861931             26/05/2022           3           F
# 1902           22884935             24/05/2022           3           F
# 2505           22884936             26/05/2022           3           M
# ...                 ...                    ...         ...         ...
# 14013          22000750             31/05/2022           4           F
# 16635          22000751             31/05/2022           5           F
# 16478          22000752             31/05/2022           4           M
# 14591          23347452             31/05/2022           3           F
# 13808          23591974             31/05/2022           4           M
#
#        COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 332                     191001000489        191001000489
# 1758                    191001000489        191001000489
# 526                     191001000489        191001000489
# 1902                    191001000489        191001000489
# 2505                    191001000489        191001000489
# ...                              ...                 ...
# 14013                   299773002598        299773000498
# 16635                   299773002598        299773000498
# 16478                   299773002598        299773000498
# 14591                   299773002598        299773000498
# 13808                   299773002598        299773000498
#
#                              COLE_NOM_ESTABLECIMIENTO  \
# 332    INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS
# 1758   INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS
# 526    INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS
# 1902   INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS
# 2505   INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS
# ...                                               ...
# 14013                      C.E. INTERNADO LA LIBERTAD
# 16635                      C.E. INTERNADO LA LIBERTAD
# 16478                      C.E. INTERNADO LA LIBERTAD
# 14591                      C.E. INTERNADO LA LIBERTAD
# 13808                      C.E. INTERNADO LA LIBERTAD
#
#                                         COLE_NOM_SEDE  COLE_COD_ICFES  \
# 332    I.E. SAGRADO CORAZON DE JESUS - SEDE PRINCIPAL           13110
# 1758   I.E. SAGRADO CORAZON DE JESUS - SEDE PRINCIPAL           13110
# 526    I.E. SAGRADO CORAZON DE JESUS - SEDE PRINCIPAL           13110
# 1902   I.E. SAGRADO CORAZON DE JESUS - SEDE PRINCIPAL           13110
# 2505   I.E. SAGRADO CORAZON DE JESUS - SEDE PRINCIPAL           13110
# ...                                               ...             ...
# 14013                         SAN ERNESTO DEL TUPARRO           67047
# 16635                         SAN ERNESTO DEL TUPARRO           67047
# 16478                         SAN ERNESTO DEL TUPARRO           67047
# 14591                         SAN ERNESTO DEL TUPARRO           67047
# 13808                         SAN ERNESTO DEL TUPARRO           67047
#
#       COLE_NATURALEZA  ... EXA_PRC_RTAS_CORR EXA_PRC_RTAS_NOCORR  \
# 332                 O  ...              40.0                60.0
# 1758                O  ...              30.0                70.0
# 526                 O  ...              40.0                60.0
# 1902                O  ...              35.0                65.0
# 2505                O  ...              70.0                30.0
# ...               ...  ...               ...                 ...
# 14013               O  ...              25.0                75.0
# 16635               O  ...              20.0                80.0
# 16478               O  ...              20.0                77.5
# 14591               O  ...              30.0                70.0
# 13808               O  ...              20.0                80.0
#
#        Ciencias Naturales Ciencias Naturales y Educación Ambiental  \
# 332                   0.0                                      0.0
# 1758                  0.0                                      0.0
# 526                   0.0                                      0.0
# 1902                  0.0                                      0.0
# 2505                  0.0                                      0.0
# ...                   ...                                      ...
# 14013                 0.0                                      0.0
# 16635                 0.0                                      4.0
# 16478                 0.0                                      0.0
# 14591                 0.0                                      0.0
# 13808                 0.0                                      0.0
#
#        Competencias Ciudadanas: Pensamiento Ciudadano  \
# 332                                               0.0
# 1758                                              0.0
# 526                                               0.0
# 1902                                              0.0
# 2505                                              0.0
# ...                                               ...
# 14013                                             0.0
# 16635                                             5.0
# 16478                                             0.0
# 14591                                             0.0
# 13808                                             0.0
#
#       Competencias Comunicativas en Lenguaje:Lectura  Inglés Lectura Crítica  \
# 332                                              8.0     0.0             0.0
# 1758                                             6.0     0.0             0.0
# 526                                              8.0     0.0             0.0
# 1902                                             7.0     0.0             0.0
# 2505                                            14.0     0.0             0.0
# ...                                              ...     ...             ...
# 14013                                            5.0     0.0             0.0
# 16635                                            4.0     0.0             0.0
# 16478                                            8.0     0.0             0.0
# 14591                                            6.0     0.0             0.0
# 13808                                            4.0     0.0             0.0
#
#       Matemáticas Sociales y Ciudadanas
# 332           0.0                   0.0
# 1758         10.0                   0.0
# 526           0.0                   0.0
# 1902         10.0                   0.0
# 2505         12.0                   0.0
# ...           ...                   ...
# 14013         4.0                   0.0
# 16635        11.0                   0.0
# 16478         5.0                   0.0
# 14591         7.0                   0.0
# 13808         7.0                   0.0
#
# [17885 rows x 36 columns]
